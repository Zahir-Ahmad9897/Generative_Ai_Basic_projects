# %%
import langchain

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import HumanMessage,SystemMessage

# %%
model=init_chat_model("groq:llama-3.1-8b-instant")
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001CB39FA53A0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001CB395278F0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_groq import ChatGroq
xyz=ChatGroq(model="llama-3.1-8b-instant")
xyz
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001CB38FF40E0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001CB3A164650>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
messeges=[
    SystemMessage("you are helpful ai tutor"),
    HumanMessage("what are the top 2 benefits of using langchain")
]

# %%
response=model.invoke(messeges)

# %%
response
# Out:
# AIMessage(content="LangChain is an open-source, Python-based framework that enables developers to build more complex and scalable AI models by combining multiple AI interfaces and models. Here are the top 2 benefits of using LangChain:\n\n1. **Unified Interface for Multiple AI Models**: LangChain provides a unified interface for integrating multiple AI models and interfaces, including but not limited to:\n\t* Large Language Models (LLMs) like LLaMA, BERT, and RoBERTa\n\t* Specialized models like AutoML and computer vision models\n\t* APIs from cloud platforms like Google Cloud, Amazon SageMaker, and Azure Machine Learning\n\nBy providing a single interface for multiple AI models, LangChain simplifies the development process and enables developers to focus on building more complex and scalable AI applications.\n\n2. **Improved Efficiency and Scalability**: LangChain's architecture enables developers to build more efficient and scalable AI models by:\n\t* Enabling parallel processing of AI tasks\n\t* Allowing for easy distribution of AI workloads across multiple machines\n\t* Providing a more modular and flexible architecture for building AI applications\n\nBy improving efficiency and scalability, LangChain enables developers to build more complex and powerful AI applications that can handle large volumes of data and tasks.\n\nThese two benefits make LangChain an attractive choice for developers who want to build more complex and scalable AI applications.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 271, 'prompt_tokens': 51, 'total_tokens': 322, 'completion_time': 0.394806692, 'prompt_time': 0.002461736, 'queue_time': 0.005313417, 'total_time': 0.397268428}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--57d88be2-f519-436c-89e8-74e5817b29c0-0', usage_metadata={'input_tokens': 51, 'output_tokens': 271, 'total_tokens': 322})

# %%
print(response.content)
# Out:
# LangChain is an open-source, Python-based framework that enables developers to build more complex and scalable AI models by combining multiple AI interfaces and models. Here are the top 2 benefits of using LangChain:
#
# 1. **Unified Interface for Multiple AI Models**: LangChain provides a unified interface for integrating multiple AI models and interfaces, including but not limited to:
# 	* Large Language Models (LLMs) like LLaMA, BERT, and RoBERTa
# 	* Specialized models like AutoML and computer vision models
# 	* APIs from cloud platforms like Google Cloud, Amazon SageMaker, and Azure Machine Learning
#
# By providing a single interface for multiple AI models, LangChain simplifies the development process and enables developers to focus on building more complex and scalable AI applications.
#
# 2. **Improved Efficiency and Scalability**: LangChain's architecture enables developers to build more efficient and scalable AI models by:
# 	* Enabling parallel processing of AI tasks
# 	* Allowing for easy distribution of AI workloads across multiple machines
# 	* Providing a more modular and flexible architecture for building AI applications
#
# By improving efficiency and scalability, LangChain enables developers to build more complex and powerful AI applications that can handle large volumes of data and tasks.
#
# These two benefits make LangChain an attractive choice for developers who want to build more complex and scalable AI applications.
