# %%
from langchain_huggingface import ChatHuggingFace,HuggingFaceEmbeddings,HuggingFaceEndpoint
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableLambda
from langchain_core.messages import BaseMessage, SystemMessage, HumanMessage, AIMessage
from transformers import AutoTokenizer
from dotenv import load_dotenv
import os

# %%
load_dotenv(dotenv_path="D:\Gen AI_LANGChain\.env")
os.environ["HUGGINGFACEHUB_API_TOKEN"]=os.getenv("HUGGINGFACEHUB_API_TOKEN")
tokenizer = AutoTokenizer.from_pretrained("Intel/neural-chat-7b-v3-1")
chat = ChatHuggingFace(
    llm=HuggingFaceEndpoint(
        repo_id="Intel/neural-chat-7b-v3-1",
        
        max_new_tokens=512
    ),
    tokenizer=tokenizer,
    verbose=True
)

# Direct messages
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Zahir Ahmad\AppData\Local\Temp\ipykernel_2944\2795862845.py:1: SyntaxWarning: invalid escape sequence '\G'
#   load_dotenv(dotenv_path="D:\Gen AI_LANGChain\.env")

# %%
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="Translate 'Hello, i am fine , how are you?' into French")
]

response = chat.invoke(messages) # Changed this line
print(response)
# Out:
# content=' "Bonjour, je suis bien, comment allez-vous ?"' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 36, 'total_tokens': 53}, 'model_name': 'Intel/neural-chat-7b-v3-1', 'system_fingerprint': '', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c5b02-38ba-7803-ae3b-9bce9f9f7be4-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 36, 'output_tokens': 17, 'total_tokens': 53}

# %% [markdown]
# Method 2:  Using Chain prompt templet

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"]=os.getenv("HUGGINGFACEHUB_API_TOKEN")

# %%
llm = HuggingFaceEndpoint(
    repo_id="Intel/neural-chat-7b-v3-1", # Updated to Intel/neural-chat-7b-v3-1
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
)


tokenizer = AutoTokenizer.from_pretrained("Intel/neural-chat-7b-v3-1") # Updated tokenizer
chat = ChatHuggingFace(llm=llm, tokenizer=tokenizer, verbose=True)
chat_template = ChatPromptTemplate.from_messages([
    SystemMessage(content="You are a helpful ai professor ."),
    HumanMessage(content="Please explain '{text}' in easy english")
])
from langchain_core.prompts import ChatPromptTemplate
chain = chat_template | chat | StrOutputParser()
response = chain.invoke({"text": "what is langchain"})
print(response)
# Out:
#  '{text}' refers to the given text or any piece of written content without enclosing any specific context or explanation. It simply means that there is some written text or it could be representing a short description or a message you want me to interpret in plain, simple language. It requires to analyze and convey the meaning of the text included within the brackets for you.

# %%
chat_template = ChatPromptTemplate.from_messages([
    SystemMessage(content="You are a helpful ai professor ."),
    HumanMessage(content="Please explain '{text}' in easy english")
])
from langchain_core.prompts import ChatPromptTemplate
chain = chat_template | chat
response = chain.invoke({"text": "what is langchain"})
print(response)
# Out:
# content=" The given phrase '{text}' simply means that there is no actual text or content within the curly brackets. Instead, it is just a placeholder for where some text is expected or defined. Think of it as an empty container that will be filled with text or information later. We don't know what should go inside from the context, but it's waiting for relevant content to be added or replaced. It's like a spot where the specifics will be filled in later, like a blank space awaiting to display or represent some words or a piece of description." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 118, 'prompt_tokens': 31, 'total_tokens': 149}, 'model_name': 'Intel/neural-chat-7b-v3-1', 'system_fingerprint': '', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c5b05-dc57-7b20-ab6e-0cae692738dd-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 31, 'output_tokens': 118, 'total_tokens': 149}
